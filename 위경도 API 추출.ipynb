# %% [markdown]
# 주소 가져오기 api 함수

# %%
import json
import requests

# %%
api_key='05c5e5b93822c0acd93e8cea0015ca13'

# %%
def addr_to_lat_lon(addr):
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query={address}'.format(address=addr)
    headers = {"Authorization": "KakaoAK " + api_key}
    result = json.loads(str(requests.get(url, headers=headers).text))
    
    if result['documents'] == []:
        return (37.565,126.986)
    else :
        match_first = result['documents'][0]['address']
    
    if  match_first == None:
        #n = result['documents'][0]['road_address']['building_name']
        #result = getXY_Keyword(n)
        return (37.565,126.986)
    return float(match_first['y']), float(match_first['x'])
    #return result

# %%
addr_to_lat_lon('서울특별시성동구금호3가동'),addr_to_lat_lon('서울특별시종로구종로1동')
# Out:
# ((37.5532931077204, 127.020918361398), (37.5709578373114, 126.977928770123))

# %%
addr_to_lat_lon('서울특별시중랑구면목본동')
# Out:
# (37.5872805191925, 127.087488538133)

# %%
ev_charger_location = []
for i in adr_list:
    ev_charger_location.append(addr_to_lat_lon(i))

# %%
ev_charger_location
# Out:
# [(37.5663174209601, 126.977829174031),
#  (37.4686148123608, 127.034104303678),
#  (37.51252777344, 126.939942092863),
#  (37.6066259706302, 127.092907592938),
#  (37.5660114536639, 126.82692745642),
#  (37.5850650584329, 126.936100906587),
#  (37.5702217430549, 126.966204176024),
#  (37.5520117024951, 127.078772391405),
#  (37.5634225092469, 127.036964999975),
#  (37.6545053561645, 127.049009479847),
#  (37.565, 126.986),
#  (37.6031675506296, 127.101931794741),
#  (37.5170753784215, 126.866542541936),
#  (37.5645541852439, 126.975613605737),
#  (37.5791546257808, 126.936759175119),
#  (37.565, 126.986),
#  (37.4702817397206, 127.128543818846),
#  (37.5393391659214, 127.123301730964),
#  (37.6027493115437, 127.081659134172),
#  (37.5722109668864, 126.805209662455),
#  (37.565, 126.986)]

# %% [markdown]
# mapbox 시각화

# %%
import mapboxgl
from mapboxgl.viz import *
import os
from mapboxgl.utils import create_color_stops

# %%
data = ev_charger_location

# %%
token = os.getenv('pk.eyJ1IjoiaHllb25qdW5nIiwiYSI6ImNsNXQ4c2F5YTA5emUzanFxazl1OXY3N2sifQ.ReHtpsRdLSNbMGMilMbwuQ')

# %%
center = [126.986,37.565]

# %%
viz = CircleViz(
    data,
    access_token = token,
    center = center,
    zoom = 10)

viz.show()
# Out:
# C:\Users\TJ\.conda\envs\py38\lib\site-packages\IPython\core\display.py:419: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe id="map", srcdoc="<!DOCTYPE html>
# <html>
# <head>
# <title>mapboxgl-jupyter viz</title>
# <meta charset='UTF-8' />
# <meta name='viewport'
#       content='initial-scale=1,maximum-scale=1,user-scalable=no' />
# <script type='text/javascript'
#         src='https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js'></script>
# <link type='text/css'
#       href='https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css'
#       rel='stylesheet' />
#
# <style type='text/css'>
#     body { margin:0; padding:0; }
#     .map { position: absolute; top:0; bottom:0; width:100%; }
#     .legend {
#         background-color: white;
#         color: #6e6e6e;
#         border-radius: 3px;
#         bottom: 10px;
#         box-shadow: 0 1px 2px rgba(0, 0, 0, 0.10);
# ...

# %% [markdown]
# <hr>

# %% [markdown]
# folium 시각화

# %%
import folium

# %%
map = folium.Map(location=[37.565, 126.986], zoom_start=11)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
center = [37.541, 126.986]
m = folium.Map(location = center, zoom_start=10)
folium.Circle(location=[37.565, 126.986], radius=200).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <hr>

# %%
#키워드 검색 함수
def getXY_Keyword(name):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json'
    params = {
        'query':name
    }
    headers = {
        'Authorization': 'KakaoAK' + api_key
    }

    result = res(url, params, headers)
    return result

# %%
#응답 함수
def res(url, params, headers):
    res = requests.get(url, params=params, headers=headers)
    if res.status_code == 200:
        return res.json()
    else:
        return ''

# %%
#카카오 지도에서 검색 링크 불러오는 함수
def kakao_search(y, x, name):
    url = f'https://dapi.kakao.com/v2/local/search/keyword.json?y={y}&x={x}&radius=50'
    params = {'query':name}
    headers = {'Authorization': 'KakaoAK' + aoi_key}
    res = requests.get(url, params=params, headers=headers)
    if res.status_code == 200:
        result = res.json()
        if result['documents'] != []:
            return result['documents'][0]['place_url']
        else:
            return ''
    else:
        print('Error code:'+res.status_code)

# %% [markdown]
# <hr>

# %% [markdown]
# 데이터 값 불러오기

# %%
import mapboxgl
from mapboxgl.viz import *
import pandas as pd

# %%
ev_charger = pd.read_csv('./data/서울특별시_소유 전기차충전소의 충전량_20220119.csv',encoding='cp949')

# %%
ev_charger = ev_charger.head(1000)

# %% [markdown]
# <hr>

# %%
ev_charger = ev_charger['주소']

# %%
ev_charger = ev_charger.drop_duplicates()

# %%
ev_charger
# Out:
# 0           중구 세종대로 110
# 1         서초구 양재동 201-1
# 3         동작구 장승배기로 161
# 5           중랑구 신내동 662
# 7          강서구 마곡중앙5로 9
# 8      서대문구 홍제1동 361-36
# 9            종로구 송월길 52
# 11          광진구 능동로 216
# 16         성동구 고산자로 270
# 17           도봉구 창동 1-9
# 24       금천구 시흥대로 153길
# 25        중랑구 망우동 353-1
# 41         양천구 목동동로 105
# 49           중구 덕수궁길 15
# 62         서대문구 연희로 248
# 75       관악구 남부순환로 163길
# 82        송파구 장지동 561-9
# 110        강동구 천호대로 997
# 111    중랑구 동일로 136나길 14
# 117         강서구 방화동 845
# 757           중구 예장동 산1
# Name: 주소, dtype: object

# %% [markdown]
# <hr>

# %%
#ev_charger = ev_charger.iloc[:,2:4].values

# %% [markdown]
# <hr>

# %%
adr_list = []
for i in ev_charger:
    adr_list.append(i)

# %%
adr_list
# Out:
# ['중구 세종대로 110',
#  '서초구 양재동 201-1',
#  '동작구 장승배기로 161',
#  '중랑구 신내동 662',
#  '강서구 마곡중앙5로 9',
#  '서대문구 홍제1동 361-36',
#  '종로구 송월길 52',
#  '광진구 능동로 216',
#  '성동구 고산자로 270',
#  '도봉구 창동 1-9',
#  '금천구 시흥대로 153길 ',
#  '중랑구 망우동 353-1',
#  '양천구 목동동로 105',
#  '중구 덕수궁길 15',
#  '서대문구 연희로 248',
#  '관악구 남부순환로 163길',
#  '송파구 장지동 561-9',
#  '강동구 천호대로 997',
#  '중랑구 동일로 136나길 14',
#  '강서구 방화동 845',
#  '중구 예장동 산1']

# %% [markdown]
# <hr>
